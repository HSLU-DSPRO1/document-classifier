# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("wcukierski/enron-email-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/wcukierski/enron-email-dataset?dataset_version_number=2...
# 100%|██████████| 358M/358M [00:23<00:00, 16.3MB/s]
# Extracting files...
# Path to dataset files: C:\Users\viach\.cache\kagglehub\datasets\wcukierski\enron-email-dataset\versions\2

# %%
# Download latest version
path = kagglehub.dataset_download("ghassenkhaled/invoices-data")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/ghassenkhaled/invoices-data?dataset_version_number=1...
# 100%|██████████| 287k/287k [00:00<00:00, 803kB/s]
# Extracting files...
# Path to dataset files: C:\Users\viach\.cache\kagglehub\datasets\ghassenkhaled\invoices-data\versions\1

# %%
path = kagglehub.dataset_download("Cornell-University/arxiv")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/Cornell-University/arxiv?dataset_version_number=258...
# 100%|██████████| 1.52G/1.52G [02:03<00:00, 13.2MB/s]
# Extracting files...
# Path to dataset files: C:\Users\viach\.cache\kagglehub\datasets\Cornell-University\arxiv\versions\258

# %%
# Download latest version
path = kagglehub.dataset_download("konradb/atticus-open-contract-dataset-aok-beta")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/konradb/atticus-open-contract-dataset-aok-beta?dataset_version_number=2...
# 100%|██████████| 102M/102M [00:08<00:00, 12.4MB/s]
# Extracting files...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Download latest version
# ----> 2 path = kagglehub.dataset_download("konradb/atticus-open-contract-dataset-aok-beta")
#       4 print("Path to dataset files:", path)
#
# File c:\Users\viach\anaconda3\Lib\site-packages\kagglehub\datasets.py:43, in dataset_download(handle, path, force_download)
#      41 h = parse_dataset_handle(handle)
#      42 logger.info(f"Downloading Dataset: {h.to_url()} ...", extra={**EXTRA_CONSOLE_BLOCK})
# ---> 43 path, _ = registry.dataset_resolver(h, path, force_download=force_download)
#      44 return path
#
# File c:\Users\viach\anaconda3\Lib\site-packages\kagglehub\registry.py:28, in MultiImplRegistry.__call__(self, *args, **kwargs)
#      26 for impl in reversed(self._impls):
#      27     if impl.is_supported(*args, **kwargs):
# ---> 28         return impl(*args, **kwargs)
#      29     else:
#      30         fails.append(type(impl).__name__)
#
# File c:\Users\viach\anaconda3\Lib\site-packages\kagglehub\resolver.py:29, in Resolver.__call__(self, handle, path, force_download)
#      15 def __call__(
#      16     self, handle: T, path: Optional[str] = None, *, force_download: Optional[bool] = False
#      17 ) -> tuple[str, Optional[int]]:
#      18     """Resolves a handle into a path with the requested file(s) and the resource's version number.
#      19
#      20     Args:
#    (...)
#      27         Some cases where version number might be missing: Competition datasource, API-based models.
#      28     """
# ---> 29     path, version = self._resolve(handle, path, force_download=force_download)
#      31     # Note handles are immutable, so _resolve() could not have altered our reference
#      32     register_datasource_access(handle, version)
#
# File c:\Users\viach\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:132, in DatasetHttpResolver._resolve(self, h, path, force_download)
#     129 # First, we download the archive.
#     130 api_client.download_file(url_path, archive_path, h)
# --> 132 _extract_archive(archive_path, out_path)
#     134 # Delete the archive
#     135 os.remove(archive_path)
#
# File c:\Users\viach\anaconda3\Lib\site-packages\kagglehub\http_resolver.py:269, in _extract_archive(archive_path, out_path)
#     267 elif zipfile.is_zipfile(archive_path):
#     268     with zipfile.ZipFile(archive_path, "r") as f:
# --> 269         f.extractall(out_path)
#     270 else:
#     271     msg = "Unsupported archive type."
#
# File c:\Users\viach\anaconda3\Lib\zipfile\__init__.py:1744, in ZipFile.extractall(self, path, members, pwd)
#    1741     path = os.fspath(path)
#    1743 for zipinfo in members:
# -> 1744     self._extract_member(zipinfo, path, pwd)
#
# File c:\Users\viach\anaconda3\Lib\zipfile\__init__.py:1801, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1797         os.mkdir(targetpath)
#    1798     return targetpath
#    1800 with self.open(member, pwd=pwd) as source, \
# -> 1801      open(targetpath, "wb") as target:
#    1802     shutil.copyfileobj(source, target)
#    1804 return targetpath
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\viach\\.cache\\kagglehub\\datasets\\konradb\\atticus-open-contract-dataset-aok-beta\\versions\\2\\CUAD_v1\\full_contract_pdf\\Part_I\\License_Agreements\\PlayboyEnterprisesInc_20090220_10-QA_EX-10.2_4091580_EX-10.2_Content License Agreement_ Marketing Agreement_ Sales-Purchase Agreement1.pdf'

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("cankatsrc/invoices")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\viach\.cache\kagglehub\datasets\cankatsrc\invoices\versions\1
