# %%
# !pip install transformers
# !pip install torch
# !pip install pillow

from transformers import AutoImageProcessor, AutoModelForImageClassification
import os

ckpt = "outputs/dit_base_rvlcdip_3cls/checkpoint-11214"
final_dir = "outputs/dit_base_rvlcdip_3cls/final"

processor = AutoImageProcessor.from_pretrained(ckpt)
model = AutoModelForImageClassification.from_pretrained(ckpt)

os.makedirs(final_dir, exist_ok=True)
processor.save_pretrained(final_dir)
model.save_pretrained(final_dir)

print("Saved inference-ready model to:", final_dir)
# Out:
# ...
#   Using cached huggingface_hub-0.36.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 95.6 MB/s eta 0:00:00
# Using cached huggingface_hub-0.36.0-py3-none-any.whl (566 kB)
# Using cached regex-2025.11.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (803 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 87.2 MB/s eta 0:00:00
# Using cached hf_xet-1.2.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
# ...
# Saved inference-ready model to: outputs/dit_base_rvlcdip_3cls/final
