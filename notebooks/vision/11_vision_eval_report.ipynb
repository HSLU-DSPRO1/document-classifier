# %% [markdown]
# # 11_vision_eval_report

# %%
from pathlib import Path
import json
import pandas as pd

cfg = json.loads(Path("../project_config.json").read_text(encoding="utf-8"))
ROOT = Path(cfg["ROOT"])
OUT_FIG_VISION = ROOT / "outputs" / "figures" / "vision_model"
OUT_FIG_VISION.mkdir(parents=True, exist_ok=True)

print("OUT_FIG_VISION:", OUT_FIG_VISION)

# %%
# Use this notebook to:
# - evaluate the vision model on a held-out set of page images
# - export confusion matrix to outputs/figures/vision_model/
# - save a short metrics table to outputs/vision_metrics.csv
